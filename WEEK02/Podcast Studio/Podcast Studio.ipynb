# %% [markdown]
# Project 1 Brief
# Project Overview
# Project Name: Podcast Studio
# Duration: 1 Type: Group Module: Module 1

# %% [markdown]
# Project 1 Brief
# Project Overview
# Project Name: Podcast Studio
# Duration: 1 Type: Group Module: Module 1
#
# Authors: Elsa, Antonio, Marco, Cindy
